# %% [markdown]
# ## Danish multilingual Analysis
#
# In this notebook we will look at the errors that our model performs in zero-shot mode.
#
# We will use a model trained on OLID

# %%
# %load_ext autoreload
# %autoreload 2
import os
from datetime import datetime
import fire
import torch
import pandas as pd
from torchtext import data
import torch.nn as nn
from transformers import (
    AdamW, BertForSequenceClassification, BertTokenizer,
    get_constant_schedule_with_warmup
)

from offenseval.nn import (
    Tokenizer,
    train, evaluate, train_cycle, save_model, load_model, evaluate_dataset
)
from offenseval.datasets import datasets

pd.options.display.max_rows = 200
pd.options.display.max_colwidth = 300

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model, TEXT = load_model("../../models/bert_cased.olid.pt", device)

# %% [markdown]
# Create fields and some other boilerplate

# %%
from offenseval.datasets import datasets, build_dataset

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Loading dataset...")
ID = data.Field(sequential=False, use_vocab=False)
SUBTASK_A = data.LabelField()


fields = {
    "id": ('id', ID),
    "text": ('text', TEXT),
    "subtask_a": ("subtask_a", SUBTASK_A)
}


test_dataset = build_dataset(datasets["danish"]["test"], fields)

SUBTASK_A.build_vocab(test_dataset)

assert SUBTASK_A.vocab.itos == ["NOT", "OFF"]
# Out:
# Loading dataset...

# %% [markdown]
# Get the predictions

# %%
from offenseval.nn.evaluation import get_outputs
from tqdm.auto import tqdm

# DON'T SORT!
test_it = data.Iterator(
    test_dataset, batch_size=1, device=device,
    shuffle=False, sort=False,
)


pred_probas, labels = get_outputs(model, tqdm(test_it))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=592.0), HTML(value='')))

# %% [markdown]
# Construct dataset for better visualization

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

true = labels
pred = (pred_probas > 0.5).float()

acc = accuracy_score(true, pred)
pos_f1 = f1_score(true, pred)
neg_f1 = f1_score(1-true, 1-pred)
avg_f1 = (pos_f1 + neg_f1) / 2

print(f'Acc: {acc*100:.2f}% Macro F1: {avg_f1:.3f} Pos F1 {pos_f1:.3f} Neg F1 {neg_f1:.3f}')
# Out:
# Acc: 79.22% Macro F1: 0.622 Pos F1 0.369 Neg F1 0.876

# %%
import pandas as pd


df_da = pd.read_table(datasets["danish"]["test"], index_col=0)

df_da["label"] = df_da["subtask_a"] == 'OFF' 
df_da["prob"] = pred_probas.view(-1) 
df_da["pred"] = df_da["prob"] > 0.5

df_da
# Out:
#                                                                                                                                                                                                                                                                                                             tweet  \
# id
# 2308                                                                                                                                                                                                                                                                                   ##15,29 CM REN DANSK MAND.
# 2083                                                                                                                                                                                                                                                                                         Er der vods et sted?
# 263                                                                                                                                                                                                                                                                                                      Og??????
# 3266                                                                                                                                                                                                                                                               Meget overraskende at Japan ikke er på listen!
# 1871                                                                                                                                                                                                                                                           jeg overvejer næsten at invitere dig på aftensmad.
# ...                                                                                                                                                                                                                                                                                                           ...
# 347   Jeg studerer selv i England, i en af de dyreste byer i landet - i forhold til Danmark så ligner det LORT. Hjemløse og folk tabt af systemet over alt, skrald over det hele, alle mine venner er ved at drukne i studie lån og meget misundelige på min SU, biler på den forkerte side a vejen... Jeg kun...
# 1395                                                                                                                                                                                                     bare hun huske at betale skat og ik kommer hjem når hun bliver syg og nasser på der danske sundhedsvæsen
# 1217                                                                                                                                                                                             nogen folk har bare ondt i røven.. men jeg forstår godt du gør det, kunne jeg måske også finde på ud i fremtiden
# 258                                                                                                                                 Han er sku da den eneste som gør noget for veteranerne i USA! Skriv lige lidt om det også, så jeres brugere ikke forledes til at tro at Trump ikke anerkender soldaters ofre!
# 1683                                                                                                                                                                                                                          Så kan det være de halvvikinger derovre kan lære at bruge Æ, Ø og Å i stedet for Z.
#
#      subtask_a  label      prob   pred
# id
# 2308       NOT  False  0.380701  False
# 2083       NOT  False  0.107194  False
# 263        NOT  False  0.159163  False
# 3266       NOT  False  0.165946  False
# 1871       NOT  False  0.163459  False
# ...        ...    ...       ...    ...
# 347        OFF   True  0.512812   True
# 1395       NOT  False  0.405745  False
# 1217       NOT  False  0.547293   True
# 258        NOT  False  0.365415  False
# 1683       NOT  False  0.226837  False
#
# [592 rows x 5 columns]

# %% [markdown]
# ## Get the translations
#
# Now, let's check out what our model predicts when using the translations of those exact texts to English.
#
# First, append the translations to the dataframe

# %%
translations = pd.read_json("../../data/translations/Danish/offenseval-da-training-v1-en.json")
translations.set_index("id", inplace=True)

df_da = pd.merge(df_da, translations, how="left", left_index=True, right_index=True)

df_da[:10]
# Out:
#                                                                                              tweet  \
# id
# 2308                                                                    ##15,29 CM REN DANSK MAND.
# 2083                                                                          Er der vods et sted?
# 263                                                                                       Og??????
# 3266                                                Meget overraskende at Japan ikke er på listen!
# 1871                                            jeg overvejer næsten at invitere dig på aftensmad.
# 181                                                         Brænd hele lortet ned og start forfra.
# 1                                                                              Satans danskjävlar!
# 2840                                                                                  Thank you :)
# 1190  Dansk propaganda hade funkar bättre om ni hade skrivit lite bättre fejk-svenska. Protip: URL
# 2689                                                Vi mangler lige Blond skiltet der blev smadret
#
#      subtask_a  label      prob   pred  \
# id
# 2308       NOT  False  0.380701  False
# 2083       NOT  False  0.107194  False
# 263        NOT  False  0.159163  False
# 3266       NOT  False  0.165946  False
# 1871       NOT  False  0.163459  False
# 181        OFF   True  0.277059  False
# 1          OFF   True  0.932986   True
# 2840       NOT  False  0.060507  False
# 1190       NOT  False  0.256336  False
# 2689       NOT  False  0.829687   True
#
#                                                                                                            en
# id
# 2308                                                                             ## 15.29 CM PURE DANISH MAN.
# 2083                                                                              Is there a place somewhere?
# 263                                                                                                 And??????
# 3266                                                           Very surprising that Japan is not on the list!
# 1871                                                       I&#39;m almost considering inviting you to dinner.
# 181                                                                  Burn the whole shit down and start over.
# 1                                                                                          Satan&#39;s devil!
# 2840                                                                                             Thank you :)
# 1190  Danish propaganda would have worked better if you had written a little better fake-Swedish. Protip: URL
# 2689                                                   We&#39;re just missing the Blond sign that was smashed

# %% [markdown]
# Now, predict the translation. We need to create examples in a different way to take the "en" field for translation

# %%
"""
We need different fields!
"""
translated_fields = {
    "id": fields["id"],
    "en": fields["text"],
    "subtask_a": fields["subtask_a"]
}

examples = [data.Example.fromdict({
    **{"id": id}, 
    **t
}, fields=translated_fields) for id, t in df_da.iterrows()]

translated_dataset = data.Dataset(examples, fields.values())

translation_it = data.Iterator(
    translated_dataset, batch_size=1, device=device,
    shuffle=False
)

translated_pred_probas, _ = get_outputs(model, tqdm(translation_it))

df_da["prob_en"] = translated_pred_probas.view(-1)
df_da["pred_en"] = df_da["prob_en"] > 0.5
# Out:
# HBox(children=(FloatProgress(value=0.0, max=592.0), HTML(value='')))

# %% [markdown]
# Let's check the results in English

# %%
true = df_da["label"]
pred = df_da["pred_en"]

acc = accuracy_score(true, pred)
pos_f1 = f1_score(true, pred)
neg_f1 = f1_score(1-true, 1-pred)
avg_f1 = (pos_f1 + neg_f1) / 2

print(f'Acc: {acc*100:.2f}% Macro F1: {avg_f1:.3f} Pos F1 {pos_f1:.3f} Neg F1 {neg_f1:.3f}')
# Out:
# Acc: 81.42% Macro F1: 0.699 Pos F1 0.513 Neg F1 0.885

# %%
true = df_da["label"]
pred = (df_da["prob"] + df_da["prob_en"])/2 > 0.5

acc = accuracy_score(true, pred)
pos_f1 = f1_score(true, pred)
neg_f1 = f1_score(1-true, 1-pred)
avg_f1 = (pos_f1 + neg_f1) / 2

print(f'Acc: {acc*100:.2f}% Macro F1: {avg_f1:.3f} Pos F1 {pos_f1:.3f} Neg F1 {neg_f1:.3f}')
# Out:
# Acc: 82.77% Macro F1: 0.711 Pos F1 0.528 Neg F1 0.895

# %% [markdown]
# So, the best is to just use *both* the original tweet, the translations, and average the probabilities

# %%
df_da["pred_prom"] = (df_da["prob"] + df_da["prob_en"])/2 > 0.5

# %% [markdown]
# ## Error Analysis

# %% [markdown]
# Let's check out the errors

# %%
errors = df_da[df_da["label"] != df_da["pred_prom"]]

false_neg = errors[errors["label"]]
false_pos = errors[~errors["label"]]


print(f"There are {len(errors)} errors (out of {len(df_da)} instances)")
print(f"{len(false_neg)} are false negatives and {len(false_pos)} are false positives")
# Out:
# There are 102 errors (out of 592 instances)
# 20 are false negatives and 82 are false positives

# %%
false_pos.sort_values("prob", ascending=False)
# Out:
#                                                                                                                                                                                                                                                                                                             tweet  \
# id
# 2597                                                                                                                                                                                                                                                  Det er fandme noget **Fallout: Nakskov** type shit, det der
# 196                                                                                                                                                                                                                så længe der er mænd som villigt betaler 5000 for et knald, det er ikke pigerne som er dumme ?
# 2303                                                                                                                                                                                                                                                                                               SKÅNE ER DANSK
# 3362                                                                                                                                                                                            Det her kommer måske til at være dumt, men det er jo 100% photoshoppet - så er jeg out of the loop? Hvad er joken
# 3489                                                                                                                                                                                                                                                                                            Kugle for panden!
# 3342                                                                                                             Kan vi ikke spare de gifteksperter vi har siddende i døgnvagt, og bruge pengene på bedre ting?    "Det skulle man tro, Hr. Løkke. Men danskerne er nogle idioter, der spiser deres stueplanter."
# 2574                                                                                                                                                                                                                                                                                                   LUK BROEN!
# 1340                                                                                                                                                                                                                                                                                  Satan er det dig?  &#x200B;
# 1927                                                                                                                                                                                                                                                            DET DER, MINE KJÆRE DANSKER, SER UTROLIG GODT UT!
# 298                                                                                                                              Hvad F..... foregår der i hovedet på folk?? Der er forhåbentlig noget videoovervågning, der kan vise, hvem de idioter er og så skal de have lov til at betale for deres hærværk.
# 2890                                                                                                                                                                                                                             Ist das ein bockwurst in dein lomme, oder bist du doch nur froh mich zu seehen ?
# 157                                                                                                                                                                                                       Godt jeg ikke kogte pastaen forkert.. @USER. Men heldigvis er du ikke sådan.. Føj hvor er det væmmeligt
# 3197                                                                                                                                                                                                                                                                        Kæft der har siddet mange klar, haha.
# 443                                                                                                                                                                                                                                                               jeg spørger lige dumt: hvad er det for et spil?
# 2250                                                                                                                                                Det er så typisk danskere at være mere ekstatiske over at vi vandt EM end at menneskeheden proppede mennesker på månen.  ^^^Jeg ^^^stemte ^^^selv ^^^på ^^^EM
# 1086  Og det bedste er at Norge ikke engang havde nogen der var grum nok til at spille bøffen, så ham måtte de importere Ove Verner Hansen fra Danmark!   Jeg foreslår at der oprettes et Olsenbanden Expeditionary Force, der kan tilkaldes til at sætte nordmænd på plads, hver gang depåstår noget så åndss...
# 2195                                                                                                                                                                                                                                                                                       Det er da dyreplageri!
# 788                                                                                                                                                                                                           Det beviser jo kun det vi andre har vidst længe: ASYLSHOPPERE der ikke er en skid i fare hjemlandet
# 2313                                                                                                                                                                                                                                                             Fyfan så fult, länge leve den svenska välfärden!
# 278                                                                                                                                                                                                                                                                        knullebehovet var sterkere enn frykten
# 119                                                                                                                                                                                                                                                                                      Der sker jo ikke en skid
# 698                                                                                                                                                                                                                                                                             Du er vidst lidt af en *skrue* OP
# 1627                                                                                                                                                                                                                                                      Nä nu jävlar, vilken av er postade de där, Danskjävlar?
# 3112                                                                                                                                                                                                                Ja, for fanden. Du kunne jo have gemt billedet i stedet for at tage et screenshot på mobilen.
# 1133                                                                                                                                                                                            Passer for skriftspråk. Dessverre ikke for talespråk, dere forstår jo ikke en dritt av hva vi sier :) Heia Norge!
# 793                                                                                                                                                                          hold da op jeg ville være i tvivl om jeg ville knalde dem om jeg fik 5000kr for det, men det er sgu da fint, for dem god arbejdslyst
#
#      subtask_a  label      prob   pred  \
# id
# 2597       NOT  False  0.972302   True
# 196        NOT  False  0.935520   True
# 2303       NOT  False  0.900015   True
# 3362       NOT  False  0.898711   True
# 3489       NOT  False  0.896978   True
# 3342       NOT  False  0.885027   True
# 2574       NOT  False  0.873045   True
# 1340       NOT  False  0.862102   True
# 1927       NOT  False  0.849911   True
# 298        NOT  False  0.847420   True
# 2890       NOT  False  0.840226   True
# 2980       NOT  False  0.837643   True
# 2689       NOT  False  0.829687   True
# 756        NOT  False  0.822692   True
# 2892       NOT  False  0.819171   True
# 2417       NOT  False  0.810945   True
# 3491       NOT  False  0.793441   True
# 1243       NOT  False  0.780453   True
# 1034       NOT  False  0.775598   True
# 683        NOT  False  0.772850   True
# 2082       NOT  False  0.752501   True
# 1093       NOT  False  0.749395   True
# 461        NOT  False  0.743915   True
# 1856       NOT  False  0.737472   True
# 2796       NOT  False  0.736935   True
# 1922       NOT  False  0.724878   True
# 3119       NOT  False  0.715868   True
# 3514       NOT  False  0.714467   True
# 994        NOT  False  0.706968   True
# 20         NOT  False  0.703499   True
# 3053       NOT  False  0.701728   True
# 2177       NOT  False  0.693326   True
# 2485       NOT  False  0.681947   True
# 2714       NOT  False  0.660013   True
# 2975       NOT  False  0.656864   True
# 2014       NOT  False  0.656268   True
# 1162       NOT  False  0.639531   True
# 561        NOT  False  0.595846   True
# 1629       NOT  False  0.590034   True
# 3598       NOT  False  0.586203   True
# 599        NOT  False  0.558625   True
# 3415       NOT  False  0.555733   True
# 90         NOT  False  0.549735   True
# 655        NOT  False  0.549495   True
# 2210       NOT  False  0.549111   True
# 2394       NOT  False  0.548975   True
# 1217       NOT  False  0.547293   True
# 3281       NOT  False  0.541324   True
# 3239       NOT  False  0.524016   True
# 32         NOT  False  0.523643   True
# 1962       NOT  False  0.520598   True
# 1877       NOT  False  0.518562   True
# 3158       NOT  False  0.509993   True
# 256        NOT  False  0.473122  False
# 942        NOT  False  0.466185  False
# 1081       NOT  False  0.465967  False
# 1980       NOT  False  0.447071  False
# 3230       NOT  False  0.432847  False
# 1482       NOT  False  0.419447  False
# 3021       NOT  False  0.419285  False
# 1335       NOT  False  0.414230  False
# 877        NOT  False  0.394708  False
# 1286       NOT  False  0.392613  False
# 1571       NOT  False  0.344515  False
# 306        NOT  False  0.339504  False
# 3443       NOT  False  0.335551  False
# 2721       NOT  False  0.329137  False
# 157        NOT  False  0.327792  False
# 3197       NOT  False  0.299812  False
# 443        NOT  False  0.299599  False
# 2250       NOT  False  0.291351  False
# 1086       NOT  False  0.279575  False
# 2195       NOT  False  0.267605  False
# 788        NOT  False  0.264312  False
# 2313       NOT  False  0.262718  False
# 278        NOT  False  0.262694  False
# 119        NOT  False  0.248790  False
# 698        NOT  False  0.248234  False
# 1627       NOT  False  0.212178  False
# 3112       NOT  False  0.182621  False
# 1133       NOT  False  0.172401  False
# 793        NOT  False  0.170732  False
#
#                                                                                                                                                                                                                                                                                                                en  \
# id
# 2597                                                                                                                                                                                                                               It&#39;s fuckin &#39;something ** Fallout: Nakskov ** type of shit, that thing
# 196                                                                                                                                                                                                               as long as there are men willing to pay 5000 for a bang, it&#39;s not the girls who are stupid?
# 2303                                                                                                                                                                                                                                                                                              Skåne is Danish
# 3362                                                                                                                                                                                                             This may sound silly, but it&#39;s 100% photoshopped - so am I out of the loop? What is the joke
# 3489                                                                                                                                                                                                                                                                                      Bullet to the forehead!
# 3342                                                                                &quot;Can&#39;t we save the marriage experts we have sitting around the clock and spend the money on better things?&quot; &quot;You should think so, Mr. Loke. But the Danes are some idiots who eat their houseplants.&quot;
# 2574                                                                                                                                                                                                                                                                                                 CLOSE BROEN!
# 1340                                                                                                                                                                                                                                                                                           Satan is that you?
# 1927                                                                                                                                                                                                                                                                  THAT, MY DEAR DANS, LOOKS EXCELLENTLY GOOD!
# 298                                                                                                                 What the F ..... is going on in people&#39;s heads ?? Hopefully there is some video surveillance that can show who the idiots are and then they should be allowed to pay for their vandalism.
# 2890                                                                                                                                                                                                                                      Is that a buck sausage in your pocket, or are you just happy to see me?
# 2980                                                                                                                                                                                                                                                                                             POKKERS PogChamp
# 2689                                                                                                                                                                                                                                                       We&#39;re just missing the Blond sign that was smashed
# 756                                                                                                                                                                                                                         See all these fake smiles, our state of being is the only human person in among them.
# 2892                                                                                                                                                                                                                                                                                               NOW IS THE CAT
# 698                                                                                                                                                                                                                                                                              You know a bit of a * screw * OP
# 1627                                                                                                                                                                                                                                                         Now damn, which one of you posted there, Dane Devil?
# 3112                                                                                                                                                                                                       Yeah, damn it. After all, you could have saved the image instead of taking a screenshot on your phone.
# 1133                                                                                                                                                                            Suitable for writing language. Unfortunately not for spoken language, you do not understand a shit of what we say :) Heia Norway!
# 793                                                                                                                                                                               hold it up I would be in doubt if I would fuck them if I got 5000kr for it, but that&#39;s fine then, for them good work desire
#
#        prob_en  pred_en  pred_prom
# id
# 2597  0.974230     True       True
# 196   0.971996     True       True
# 2303  0.113720    False       True
# 3362  0.414403    False       True
# 3489  0.890928     True       True
# 3342  0.940762     True       True
# 2574  0.672428     True       True
# 1340  0.932274     True       True
# 1927  0.714277     True       True
# 298   0.962680     True       True
# 2890  0.946153     True       True
# 2980  0.837643     True       True
# 2689  0.912558     True       True
# 756   0.317093    False       True
# 2892  0.546270     True       True
# 2417  0.785332     True       True
# 3491  0.946236     True       True
# 1243  0.622655     True       True
# 1034  0.471528    False       True
# 683   0.794206     True       True
# 2082  0.848421     True       True
# 1093  0.946261     True       True
# 461   0.826756     True       True
# 1856  0.898780     True       True
# 2796  0.921717     True       True
# 1922  0.337185    False       True
# 3119  0.295589    False       True
# 3514  0.288410    False       True
# 994   0.575090     True       True
# 20    0.895064     True       True
# 3053  0.773034     True       True
# 2177  0.514521     True       True
# 2485  0.600587     True       True
# 2714  0.612273     True       True
# 2975  0.652305     True       True
# 2014  0.630200     True       True
# 1162  0.641154     True       True
# 561   0.789570     True       True
# 1629  0.418396    False       True
# 3598  0.586203     True       True
# 599   0.680726     True       True
# 3415  0.957350     True       True
# 90    0.492849    False       True
# 655   0.867555     True       True
# 2210  0.816878     True       True
# 2394  0.457750    False       True
# 1217  0.971025     True       True
# 3281  0.894500     True       True
# 3239  0.792462     True       True
# 32    0.835788     True       True
# 1962  0.769570     True       True
# 1877  0.720386     True       True
# 3158  0.959132     True       True
# 256   0.878351     True       True
# 942   0.922221     True       True
# 1081  0.973867     True       True
# 1980  0.873263     True       True
# 3230  0.972274     True       True
# 1482  0.926952     True       True
# 3021  0.847688     True       True
# 1335  0.748790     True       True
# 877   0.966216     True       True
# 1286  0.707731     True       True
# 1571  0.972434     True       True
# 306   0.676848     True       True
# 3443  0.717479     True       True
# 2721  0.859055     True       True
# 157   0.882972     True       True
# 3197  0.752331     True       True
# 443   0.966724     True       True
# 2250  0.726785     True       True
# 1086  0.842876     True       True
# 2195  0.909223     True       True
# 788   0.751427     True       True
# 2313  0.875584     True       True
# 278   0.972282     True       True
# 119   0.974996     True       True
# 698   0.949143     True       True
# 1627  0.959977     True       True
# 3112  0.959109     True       True
# 1133  0.973622     True       True
# 793   0.972345     True       True

# %% [markdown]
# ## False Negative

# %%
false_neg.sort_values("prob", ascending=True)
# Out:
#                                                                                                                                                                                                                                                                                                             tweet  \
# id
# 2065                                                                                                                                                                                                                                                                                                          URL
# 2415                                                                                                                                                                                                                                                                                                  *Danskjävel
# 2704                                                                                                                                                                                                                                                                                               Danske javle!!
# 3224                                                                                                                                                                                                                                                                                 Hun er nok elendigt opdraget
# 1860                                                                                                                                                                                                                              Jeg ved sgu ikke om jeg havde lyst til at få at vide Malmö nu var vores ansvar.
# 1322                                                                                                                                                                                                                                      Der er tale om tre unge mænd af udenlandsk afstamning Surprise surprise
# 3438                                                                                                                                                                                                                                                             Det er fandme et stærkt album! Tak for grinet :)
# 1309                                                                                                                                                                              @USER ro og orden i Afrika. tror du selv på den. de har altid ført stamme/ hullabulla krige der nede. og det vil de altid gøre.
# 1306                                                                                                                                                                                                                                                                    Igen en ubegavet kvinde , som får taletid
# 1538  Det er så typisk danskere det her..  Typisk dansk sommer: "det regner for meget, det er en dårlig sommer, Jeg rejser fandme sydpå hvor det er dejligt varmt"   2018 - rekord sommer! "det er for varmt, der er for tørt, Jeg må ikke grille, Jeg kan ikke spille computer, min røv sveder osv. "   Den h...
# 3000                                                                                                                                                                                                                                                  Det er fandme de bedste nyheder idag. Vi burde dele en skål
# 486                                                                                                                                                                                                                                                                                                     Møgunger.
# 3232                                                                                                                                                                                                                                                                                                   Analgafler
# 617                                                                                                                                                                                                                                                                                            Norge^har^Pusur...
# 824                                                                                                                                                                                                                                                              Fandme heller ikke noget værre end udkogt pasta.
# 548   Det er værd at huske på at Canada ifølge mange canadiere er på randen til økonomisk kollaps. Det går altså ikke skidegodt i landet og samarbejdet med andre lande, heriblandt USA er blevet langt dårligere med Trump m.m. Derudover driver Kina rovdrift på landet og er ved at puste endnu en boligbob...
# 265                                                                                                                                                                                                                                          Ingenting er mer gøy enn å gi svensken en skikkelig smekk på rumpen!
# 1974                                                                                                                                                                                                                                                                      RIP Svensken, du vil ikke blive savnet.
# 2533                                                                                                                                                                                                                                  Vi gider sgu kun have skåne halland og blekinge, resten kan de sgu beholde.
# 2598                                                                                                                                                                                                                                   Lel hvor har du fundet den? Det er vidst det jeg ville kalde et tamt meme.
#
#      subtask_a  label      prob   pred  \
# id
# 2065       OFF   True  0.089447  False
# 2415       OFF   True  0.134430  False
# 2704       OFF   True  0.143450  False
# 3224       OFF   True  0.148922  False
# 1860       OFF   True  0.151056  False
# 1322       OFF   True  0.179219  False
# 3438       OFF   True  0.182544  False
# 1309       OFF   True  0.246212  False
# 1306       OFF   True  0.250555  False
# 1538       OFF   True  0.270191  False
# 3000       OFF   True  0.281164  False
# 486        OFF   True  0.299940  False
# 3232       OFF   True  0.303448  False
# 617        OFF   True  0.315921  False
# 824        OFF   True  0.329557  False
# 548        OFF   True  0.349395  False
# 265        OFF   True  0.353648  False
# 1974       OFF   True  0.368955  False
# 2533       OFF   True  0.396254  False
# 2598       OFF   True  0.449690  False
#
#                                                                                                                                                                                                                                                                                                                en  \
# id
# 2065                                                                                                                                                                                                                                                                                                          URL
# 2415                                                                                                                                                                                                                                                                                                 * Danskjävel
# 2704                                                                                                                                                                                                                                                                                            Danish javelin !!
# 3224                                                                                                                                                                                                                                                                      She&#39;s probably miserably brought up
# 1860                                                                                                                                                                                                                                      I don&#39;t even know if I wanted to know Malmö was our responsibility.
# 1322                                                                                                                                                                                                                                   &quot;These are three young men of foreign descent&quot; Surprise surprise
# 3438                                                                                                                                                                                                                                                             It&#39;s a strong album! Thanks for the laugh :)
# 1309                                                                                                                                                            @USER peace and order in Africa. do you believe in it yourself. they have always waged tribal / hullabulla wars down there. and they always will.
# 1306                                                                                                                                                                                                                                                                  Again, a gifted woman who gets talking time
# 1538  It is so typical Danes this .. Typical Danish summer: &quot;it is raining too much, it is a bad summer, I travel to the south where it is nice warm&quot; 2018 - record summer! &quot;it&#39;s too hot, it&#39;s too dry, I can&#39;t grill, I can&#39;t play computer, my ass sweats, etc.&quot; This s...
# 3000                                                                                                                                                                                                                                                       That&#39;s the best news today. We should share a bowl
# 486                                                                                                                                                                                                                                                                                                        Brats.
# 3232                                                                                                                                                                                                                                                                                                   Anal Forks
# 617                                                                                                                                                                                                                                                                                      Norway has ^ ^ Pusur ...
# 824                                                                                                                                                                                                                                                                  Fandme also nothing worse than cooked pasta.
# 548   It is worth remembering that, according to many Canadians, Canada is on the verge of economic collapse. So it is not doing well in the country and cooperation with other countries, including the US has become far worse with Trump, etc. In addition, China is raging in the country and is inflating...
# 265                                                                                                                                                                                                                                           Nothing is more fun than giving the Swede a good taste on the butt!
# 1974                                                                                                                                                                                                                                                                       RIP The Swede, you will not be missed.
# 2533                                                                                                                                                                                                                                        We only wish to have nice palms and bleaches, the rest they can keep.
# 2598                                                                                                                                                                                                                                        Lel where did you find it? It is known what I would call a tame meme.
#
#        prob_en  pred_en  pred_prom
# id
# 2065  0.089447    False      False
# 2415  0.134430    False      False
# 2704  0.232260    False      False
# 3224  0.163593    False      False
# 1860  0.121207    False      False
# 1322  0.075737    False      False
# 3438  0.052110    False      False
# 1309  0.097953    False      False
# 1306  0.079138    False      False
# 1538  0.322134    False      False
# 3000  0.062788    False      False
# 486   0.266919    False      False
# 3232  0.281909    False      False
# 617   0.332772    False      False
# 824   0.353553    False      False
# 548   0.258354    False      False
# 265   0.532895     True      False
# 1974  0.099664    False      False
# 2533  0.106636    False      False
# 2598  0.256725    False      False

# %%
from offenseval.nn.evaluation import predict_sentence

def predict(sentence):
    return predict_sentence(model, TEXT, sentence)

predict("Brat!")
# Out:
# 0.14752325415611267

# %%
predict("Analgafler")
# Out:
# 0.303447961807251

# %%
predict("Hold dig væk fra vores ø, du dansker lort.")
# Out:
# 0.33479517698287964

# %% [markdown]
# Why this is different from the previous prediction?

# %%
df_da.loc[858].tweet
# Out:
# 'Det her er vitterligt lort. 0/10.'

# %%
predict(df_da.loc[858].tweet)
# Out:
# 0.34360530972480774

# %%
predict(df_da.loc[858].en)
# Out:
# 0.9733139872550964

# %%
predict(df_da.loc[1408].en)
# Out:
# 0.8865303993225098

# %%
predict(df_da.loc[1408].tweet)
# Out:
# 0.43442046642303467

# %% [markdown]
# ## Differences between calculations
#
# Are there a number of differences when predicting using the `predict_sentence` and using the iterators?

# %%
import math
close = 0

for _, row in df_da.iterrows():
    pred = predict(row.en)
    #print(pred, row.prob)
    close += int(math.isclose(pred, row.prob_en, abs_tol=0.05))
    
close / len(df_da)
# Out:
# 0.9408783783783784

# %% [markdown]
# Ok, yes, there are...
