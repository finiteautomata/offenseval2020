# %% [markdown]
# ## Danish multilingual Analysis
#
# In this notebook we will look at the errors that our model performs in zero-shot mode.
#
# We will use a model trained on OLID

# %%
# %load_ext autoreload
# %autoreload 2
import os
from datetime import datetime
import fire
import torch
import pandas as pd
from torchtext import data
import torch.nn as nn
from transformers import (
    AdamW, BertForSequenceClassification, BertTokenizer,
    get_constant_schedule_with_warmup
)

from offenseval.nn import (
    Tokenizer,
    train, evaluate, train_cycle, save_model, load_model, evaluate_dataset
)
from offenseval.datasets import datasets

pd.options.display.max_rows = 200
pd.options.display.max_colwidth = 300

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

model, TEXT = load_model("../../models/bert_cased.olid.pt", device)

# %%
loss, acc, f1, pos_f1, neg_f1 = evaluate_dataset(
    model, TEXT, datasets["danish"]["test"], batch_size=64
)
print(f'Test Loss: {loss:.3f}  Acc: {acc*100:.2f}% Macro F1: {f1:.3f} Pos F1 {pos_f1:.3f} Neg F1 {neg_f1:.3f}')
# Out:
# Loading dataset...
# Building iterators
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# Test Loss: 0.713  Acc: 44.93% Macro F1: 0.415 Pos F1 0.272 Neg F1 0.557

# %% [markdown]
# Create fields and some other boilerplate

# %%
from offenseval.datasets import datasets, build_dataset

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Loading dataset...")
ID = data.Field(sequential=False, use_vocab=False)
SUBTASK_A = data.LabelField()


fields = {
    "id": ('id', ID),
    "text": ('text', TEXT),
    "subtask_a": ("subtask_a", SUBTASK_A)
}


test_dataset = build_dataset(datasets["danish"]["test"], fields)

SUBTASK_A.build_vocab(test_dataset)

assert SUBTASK_A.vocab.itos == ["NOT", "OFF"]
# Out:
# Loading dataset...

# %% [markdown]
# Get the predictions

# %%
from offenseval.nn.evaluation import get_outputs
from tqdm.auto import tqdm

# DON'T SORT!
test_it = data.Iterator(
    test_dataset, batch_size=1, device=device,
    shuffle=False, sort=False,
)


pred_probas, labels = get_outputs(model, tqdm(test_it))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=592.0), HTML(value='')))

# %% [markdown]
# Construct dataset for better visualization

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score

true = labels
pred = (pred_probas > 0.5).float()

acc = accuracy_score(true, pred)
pos_f1 = f1_score(true, pred)
neg_f1 = f1_score(1-true, 1-pred)
avg_f1 = (pos_f1 + neg_f1) / 2
roc = roc_auc_score(true, pred_probas)

print(f'Acc: {acc*100:.2f}% Macro F1: {avg_f1:.3f} Pos F1 {pos_f1:.3f} Neg F1 {neg_f1:.3f} ROC {roc:.3f}')
# Out:
# Acc: 79.22% Macro F1: 0.622 Pos F1 0.369 Neg F1 0.876 ROC 0.744

# %%
import pandas as pd


df_da = pd.read_table(datasets["danish"]["test"], index_col=0)

df_da["label"] = df_da["subtask_a"] == 'OFF' 
df_da["prob"] = pred_probas.view(-1) 
df_da["pred"] = df_da["prob"] > 0.5

df_da
# Out:
#                                                                                                                                                                                                                                                                                                             tweet  \
# id
# 2308                                                                                                                                                                                                                                                                                   ##15,29 CM REN DANSK MAND.
# 2083                                                                                                                                                                                                                                                                                         Er der vods et sted?
# 263                                                                                                                                                                                                                                                                                                      Og??????
# 3266                                                                                                                                                                                                                                                               Meget overraskende at Japan ikke er på listen!
# 1871                                                                                                                                                                                                                                                           jeg overvejer næsten at invitere dig på aftensmad.
# ...                                                                                                                                                                                                                                                                                                           ...
# 347   Jeg studerer selv i England, i en af de dyreste byer i landet - i forhold til Danmark så ligner det LORT. Hjemløse og folk tabt af systemet over alt, skrald over det hele, alle mine venner er ved at drukne i studie lån og meget misundelige på min SU, biler på den forkerte side a vejen... Jeg kun...
# 1395                                                                                                                                                                                                     bare hun huske at betale skat og ik kommer hjem når hun bliver syg og nasser på der danske sundhedsvæsen
# 1217                                                                                                                                                                                             nogen folk har bare ondt i røven.. men jeg forstår godt du gør det, kunne jeg måske også finde på ud i fremtiden
# 258                                                                                                                                 Han er sku da den eneste som gør noget for veteranerne i USA! Skriv lige lidt om det også, så jeres brugere ikke forledes til at tro at Trump ikke anerkender soldaters ofre!
# 1683                                                                                                                                                                                                                          Så kan det være de halvvikinger derovre kan lære at bruge Æ, Ø og Å i stedet for Z.
#
#      subtask_a  label      prob   pred
# id
# 2308       NOT  False  0.380701  False
# 2083       NOT  False  0.107194  False
# 263        NOT  False  0.159163  False
# 3266       NOT  False  0.165946  False
# 1871       NOT  False  0.163459  False
# ...        ...    ...       ...    ...
# 347        OFF   True  0.512812   True
# 1395       NOT  False  0.405745  False
# 1217       NOT  False  0.547293   True
# 258        NOT  False  0.365415  False
# 1683       NOT  False  0.226837  False
#
# [592 rows x 5 columns]

# %% [markdown]
# ## Get the translations
#
# Now, let's check out what our model predicts when using the translations of those exact texts to English.
#
# First, append the translations to the dataframe

# %%
translations = pd.read_json("../../data/translations/Danish/offenseval-da-training-v1-en.json")
translations.set_index("id", inplace=True)

df_da = pd.merge(df_da, translations, how="left", left_index=True, right_index=True)

df_da[:10]
# Out:
#                                                                                              tweet  \
# id
# 2308                                                                    ##15,29 CM REN DANSK MAND.
# 2083                                                                          Er der vods et sted?
# 263                                                                                       Og??????
# 3266                                                Meget overraskende at Japan ikke er på listen!
# 1871                                            jeg overvejer næsten at invitere dig på aftensmad.
# 181                                                         Brænd hele lortet ned og start forfra.
# 1                                                                              Satans danskjävlar!
# 2840                                                                                  Thank you :)
# 1190  Dansk propaganda hade funkar bättre om ni hade skrivit lite bättre fejk-svenska. Protip: URL
# 2689                                                Vi mangler lige Blond skiltet der blev smadret
#
#      subtask_a  label      prob   pred  \
# id
# 2308       NOT  False  0.380701  False
# 2083       NOT  False  0.107194  False
# 263        NOT  False  0.159163  False
# 3266       NOT  False  0.165946  False
# 1871       NOT  False  0.163459  False
# 181        OFF   True  0.277059  False
# 1          OFF   True  0.932986   True
# 2840       NOT  False  0.060507  False
# 1190       NOT  False  0.256336  False
# 2689       NOT  False  0.829687   True
#
#                                                                                                            en
# id
# 2308                                                                             ## 15.29 CM PURE DANISH MAN.
# 2083                                                                              Is there a place somewhere?
# 263                                                                                                 And??????
# 3266                                                           Very surprising that Japan is not on the list!
# 1871                                                       I&#39;m almost considering inviting you to dinner.
# 181                                                                  Burn the whole shit down and start over.
# 1                                                                                          Satan&#39;s devil!
# 2840                                                                                             Thank you :)
# 1190  Danish propaganda would have worked better if you had written a little better fake-Swedish. Protip: URL
# 2689                                                   We&#39;re just missing the Blond sign that was smashed

# %% [markdown]
# Now, predict. We need to create examples in a different way to take the "en" field for translation

# %%
"""
We need different fields!
"""
translated_fields = {
    "id": fields["id"],
    "en": fields["text"],
    "subtask_a": fields["subtask_a"]
}

examples = [data.Example.fromdict({
    **{"id": id}, 
    **t
}, fields=translated_fields) for id, t in df_da.iterrows()]

translated_dataset = data.Dataset(examples, fields.values())

test_it = data.Iterator(
    translated_dataset, batch_size=1, device=device,
)

translated_pred_probas, _ = get_outputs(model, tqdm(test_it))

df_da["prob_en"] = translated_pred_probas.view(-1)
df_da["pred_en"] = df_da["prob_en"] > 0.5
# Out:
# HBox(children=(FloatProgress(value=0.0, max=592.0), HTML(value='')))

# %% [markdown]
# Let's check the results in English

# %%
true = labels
pred = (df_da["prob_en"] > 0.5)

acc = accuracy_score(true, pred)
pos_f1 = f1_score(true, pred)
neg_f1 = f1_score(1-true, 1-pred)
avg_f1 = (pos_f1 + neg_f1) / 2

print(f'Acc: {acc*100:.2f}% Macro F1: {avg_f1:.3f} Pos F1 {pos_f1:.3f} Neg F1 {neg_f1:.3f}')
# Out:
# Acc: 67.23% Macro F1: 0.470 Pos F1 0.142 Neg F1 0.797

# %% [markdown]
# ## Error Analysis

# %% [markdown]
# Let's check out the errors

# %%
errors = df_da[df_da["label"] != df_da["pred"]]

false_neg = errors[errors["label"]]
false_pos = errors[~errors["label"]]


print(f"There are {len(errors)} errors (out of {len(df_da)} instances)")
print(f"{len(false_neg)} are false negatives and {len(false_pos)} are false positives")
# Out:
# There are 123 errors (out of 592 instances)
# 41 are false negatives and 82 are false positives

# %%
false_pos.sort_values("prob", ascending=False)
# Out:
#                                                                                                                                                                                                                                                                                tweet  \
# id
# 2597                                                                                                                                                                                                                     Det er fandme noget **Fallout: Nakskov** type shit, det der
# 196                                                                                                                                                                                   så længe der er mænd som villigt betaler 5000 for et knald, det er ikke pigerne som er dumme ?
# 2303                                                                                                                                                                                                                                                                  SKÅNE ER DANSK
# 3198                                                                                                                                                                                                                Fantastisk. Hvis ikke jeg havde været fattig havde du fået guld.
# 3362                                                                                                                                                               Det her kommer måske til at være dumt, men det er jo 100% photoshoppet - så er jeg out of the loop? Hvad er joken
# 3489                                                                                                                                                                                                                                                               Kugle for panden!
# 3342                                                                                Kan vi ikke spare de gifteksperter vi har siddende i døgnvagt, og bruge pengene på bedre ting?    "Det skulle man tro, Hr. Løkke. Men danskerne er nogle idioter, der spiser deres stueplanter."
# 2574                                                                                                                                                                                                                                                                      LUK BROEN!
# 1340                                                                                                                                                                                                                                                     Satan er det dig?  &#x200B;
# 1927                                                                                                                                                                                                                               DET DER, MINE KJÆRE DANSKER, SER UTROLIG GODT UT!
# 298                                                                                                 Hvad F..... foregår der i hovedet på folk?? Der er forhåbentlig noget videoovervågning, der kan vise, hvem de idioter er og så skal de have lov til at betale for deres hærværk.
# 2890                                                                                                                                                                                                Ist das ein bockwurst in dein lomme, oder bist du doch nur froh mich zu seehen ?
# 2980                                                                                                                                                                                                                                                                POKKERS PogChamp
# 2689                                                                                                                                                                                                                                  Vi mangler lige Blond skiltet der blev smadret
# 756                                                                                                                                                                                         Se alle disse falske smil, vore mæjestat er den eneste menneskelige person i blandt dem.
# 1287                                                                                                                 Nu må i ikke være så hårde ved Dansk Røde Kors, i skal tænke på at der skal være plads til en lønforhøjelse til cheferne, de skal da for hulen ikke sulte......
# 3120                                                                                                                                                                                                                                                           VI SEJLER OP AD ÅGEN!
# 3083                                                                                                                                                                                                                                                                         HELVETE
# 289                                                                                                                                                                                                                            @USER næste gang du putter cocktail pølser på pizzaen
# 220                                                                                                                                                                                                                                                                      haha nuttet
# 1894                                                                                                                                                                                                                                    Syntes nu det skulle have været smørrebrød..
#
#      subtask_a  label      prob  pred  \
# id
# 2597       NOT  False  0.972302  True
# 196        NOT  False  0.935520  True
# 2303       NOT  False  0.900015  True
# 3198       NOT  False  0.898958  True
# 3362       NOT  False  0.898711  True
# 3489       NOT  False  0.896978  True
# 3342       NOT  False  0.885027  True
# 2574       NOT  False  0.873045  True
# 1340       NOT  False  0.862102  True
# 1927       NOT  False  0.849911  True
# 298        NOT  False  0.847420  True
# 2890       NOT  False  0.840226  True
# 2980       NOT  False  0.837643  True
# 2689       NOT  False  0.829687  True
# 756        NOT  False  0.822692  True
# 2892       NOT  False  0.819171  True
# 2417       NOT  False  0.810945  True
# 3491       NOT  False  0.793441  True
# 1243       NOT  False  0.780453  True
# 1034       NOT  False  0.775598  True
# 683        NOT  False  0.772850  True
# 2431       NOT  False  0.764267  True
# 2082       NOT  False  0.752501  True
# 1093       NOT  False  0.749395  True
# 461        NOT  False  0.743915  True
# 1856       NOT  False  0.737472  True
# 2802       NOT  False  0.737088  True
# 2796       NOT  False  0.736935  True
# 1711       NOT  False  0.732499  True
# 1922       NOT  False  0.724878  True
# 3119       NOT  False  0.715868  True
# 3514       NOT  False  0.714467  True
# 994        NOT  False  0.706968  True
# 20         NOT  False  0.703499  True
# 3053       NOT  False  0.701728  True
# 2177       NOT  False  0.693326  True
# 2485       NOT  False  0.681947  True
# 3156       NOT  False  0.677252  True
# 2692       NOT  False  0.672899  True
# 2714       NOT  False  0.660013  True
# 2975       NOT  False  0.656864  True
# 2014       NOT  False  0.656268  True
# 1162       NOT  False  0.639531  True
# 1274       NOT  False  0.625967  True
# 3237       NOT  False  0.625543  True
# 1426       NOT  False  0.622916  True
# 1802       NOT  False  0.603848  True
# 3134       NOT  False  0.602218  True
# 561        NOT  False  0.595846  True
# 1629       NOT  False  0.590034  True
# 728        NOT  False  0.589218  True
# 3598       NOT  False  0.586203  True
# 1289       NOT  False  0.583309  True
# 2524       NOT  False  0.579137  True
# 107        NOT  False  0.562247  True
# 599        NOT  False  0.558625  True
# 3415       NOT  False  0.555733  True
# 90         NOT  False  0.549735  True
# 655        NOT  False  0.549495  True
# 2210       NOT  False  0.549111  True
# 2394       NOT  False  0.548975  True
# 1217       NOT  False  0.547293  True
# 3131       NOT  False  0.545265  True
# 3281       NOT  False  0.541324  True
# 3142       NOT  False  0.531637  True
# 3098       NOT  False  0.530341  True
# 2072       NOT  False  0.530154  True
# 1758       NOT  False  0.529703  True
# 887        NOT  False  0.527035  True
# 3239       NOT  False  0.524016  True
# 32         NOT  False  0.523643  True
# 1962       NOT  False  0.520598  True
# 1758                                                                                                                                                   As such a perfectionist as I am, wouldn’t it be good to give the bullets to the rifle a small recolor?
# 887                                                                                                                                                       There has been chaos here for about 8 years now. Thank you, the moderates and the Social Democrats!
# 3239                                                                                                                                                                                                                          Just be glad it&#39;s not snuff
# 32                                                                                                                                                                                                                       Teddy&#39;s Christmas trip was dope.
# 1962                Pia shed a tear when she saw this beautiful picture of a border bomb. If ever there is something that has managed to keep the pagan hordes from east and south out of our beautiful country. Then it&#39;s Dannevirke and a border bomber
# 1877                                                                                                                                                                      It is probably the Swede who is to blame for there is never honey in the Honey Pot!
# 1650                                                                                                                                                                                                                                red sausages for everyone
# 3444                                                                                                                                                             No liver paste? And the monkey of wood. I don&#39;t know what it is and have never seen one.
# 3158                                                                                                                                                              * they see them rolling * * they hate * * patrol, they try to catch &#39;em running dirty *
# 1287                                                                             Now you must not be so hard at the Danish Red Cross, you must think that there must be room for a salary increase for the managers, they must not starve for the cave ......
# 3120                                                                                                                                                                                                                                          WE SAY UP YEAR!
# 3083                                                                                                                                                                                                                                                  Helvete
# 289                                                                                                                                                                                                @USER the next time you put cocktail sausages on the pizza
# 220                                                                                                                                                                                                                                                 haha cute
# 1894                                                                                                                                                                                                             Seemed now it should have been sandwiches ..
#
#        prob_en  pred_en
# id
# 2597  0.973622     True
# 196   0.965079     True
# 2303  0.934360     True
# 3198  0.216345    False
# 3362  0.076652    False
# 3489  0.168349    False
# 3342  0.151516    False
# 2574  0.099021    False
# 1340  0.125945    False
# 1927  0.167140    False
# 298   0.126773    False
# 2890  0.093437    False
# 2980  0.451803    False
# 2689  0.107632    False
# 756   0.111011    False
# 2892  0.302078    False
# 2417  0.971996     True
# 3491  0.143576    False
# 1243  0.057365    False
# 1034  0.972464     True
# 683   0.970934     True
# 2431  0.268761    False
# 2082  0.256725    False
# 1093  0.616878     True
# 461   0.972933     True
# 1856  0.048002    False
# 2802  0.069784    False
# 2796  0.119942    False
# 1711  0.973101     True
# 1922  0.562222     True
# 3119  0.972274     True
# 3514  0.067837    False
# 994   0.099376    False
# 20    0.921717     True
# 3053  0.144087    False
# 2177  0.083081    False
# 2485  0.462503    False
# 3156  0.847688     True
# 2692  0.081054    False
# 2714  0.652305     True
# 2975  0.115969    False
# 2014  0.091037    False
# 1162  0.056867    False
# 1274  0.135013    False
# 3237  0.163036    False
# 1426  0.971171     True
# 1802  0.159289    False
# 3134  0.971212     True
# 561   0.142116    False
# 1629  0.074675    False
# 728   0.204573    False
# 3598  0.441758    False
# 1289  0.072450    False
# 2524  0.829792     True
# 107   0.124849    False
# 599   0.160624    False
# 3415  0.146877    False
# 90    0.063324    False
# 655   0.922221     True
# 2210  0.215372    False
# 2394  0.471528    False
# 1217  0.972160     True
# 3131  0.097534    False
# 3281  0.644840     True
# 3142  0.074059    False
# 3098  0.204180    False
# 2072  0.894500     True
# 1758  0.304133    False
# 887   0.064964    False
# 3239  0.959977     True
# 32    0.101349    False
# 1962  0.375418    False
# 1877  0.304004    False
# 1650  0.171796    False
# 3444  0.152886    False
# 3158  0.128773    False
# 1287  0.109659    False
# 3120  0.962680     True
# 3083  0.667456     True
# 289   0.093899    False
# 548   Det er værd at huske på at Canada ifølge mange canadiere er på randen til økonomisk kollaps. Det går altså ikke skidegodt i landet og samarbejdet med andre lande, heriblandt USA er blevet langt dårligere med Trump m.m. Derudover driver Kina rovdrift på landet og er ved at puste endnu en boligbob...
# 265                                                                                                                                                                                                                                          Ingenting er mer gøy enn å gi svensken en skikkelig smekk på rumpen!
# 858                                                                                                                                                                                                                                                                             Det her er vitterligt lort. 0/10.
# 1974                                                                                                                                                                                                                                                                      RIP Svensken, du vil ikke blive savnet.
# 3301                                                                                                                                             Du kan klarer den fyr, stort set alle min venner er på vej ud på samme spor, hold kæft hvor føler jeg mig ensom, når alt folk omkring mig vil er at snakke drugs
# 2533                                                                                                                                                                                                                                  Vi gider sgu kun have skåne halland og blekinge, resten kan de sgu beholde.
# 1010                                                                                                                                Paraply betyder regnskærm på fransk. Regnvejr som undskyldning for at aflyse? Der må være en anden grund. Måske de horder af antifa og andet afskum, der vil slå Trump ihjel.
# 458                                                                                                                Så justitsministeren, som jeg formoder har en hovedrolle inden for bekæmpelse af stofmisbrug, har ikke den fjerneste anelse om hvor farlige de enkelte stoffer er?  De er skøre, de svenskere.
# 1408                                                                                                                                                             Se lige alle de kristne der råber og skriger om at OP skal tæskes pga et provokerende opslag!! Nårh nej vent, jeg tænker på muslimer. Min fejl.
# 273                                                                                                                                                                                                                                          Jeg vil aldrig mere klage over en lorte sommer.. Bare giv mig regn..
# 2598                                                                                                                                                                                                                                   Lel hvor har du fundet den? Det er vidst det jeg ville kalde et tamt meme.
# 835                                                                                                                                                                                                                                              Helt enig med KU. Offentlige socialister bare grådige pattebørn.
# 1028                                                                                                                                                                                                                   Hvorfor er svensken så humorforladt og skindød? Og lad da så for helvede Skåne komme hjem.
#
#      subtask_a  label      prob   pred  \
# id
# 2065       OFF   True  0.089447  False
# 1017       OFF   True  0.130515  False
# 2415       OFF   True  0.134430  False
# 2704       OFF   True  0.143450  False
# 3224       OFF   True  0.148922  False
# 1860       OFF   True  0.151056  False
# 1541       OFF   True  0.160900  False
# 1322       OFF   True  0.179219  False
# 1174       OFF   True  0.182341  False
# 3438       OFF   True  0.182544  False
# 165        OFF   True  0.203450  False
# 293        OFF   True  0.240785  False
# 3220       OFF   True  0.245081  False
# 1309       OFF   True  0.246212  False
# 1306       OFF   True  0.250555  False
# 3595       OFF   True  0.267171  False
# 875        OFF   True  0.267963  False
# 1538       OFF   True  0.270191  False
# 3254       OFF   True  0.273841  False
# 181        OFF   True  0.277059  False
# 3000       OFF   True  0.281164  False
# 810        OFF   True  0.291988  False
# 486        OFF   True  0.299940  False
# 3232       OFF   True  0.303448  False
# 617        OFF   True  0.315921  False
# 824        OFF   True  0.329557  False
# 1155       OFF   True  0.334795  False
# 909        OFF   True  0.341515  False
# 548        OFF   True  0.349395  False
# 265        OFF   True  0.353648  False
# 858        OFF   True  0.355270  False
# 1974       OFF   True  0.368955  False
# 3301       OFF   True  0.379454  False
# 2533       OFF   True  0.396254  False
# 1010       OFF   True  0.397415  False
# 458        OFF   True  0.425285  False
# 1408       OFF   True  0.434420  False
# 858                                                                                                                                                                                                                                                                                    This is really shit. 0/10.
# 1974                                                                                                                                                                                                                                                                       RIP The Swede, you will not be missed.
# 3301                                                                                                                                                      You can handle that guy, pretty much all my friends are on the same track, shut up where I feel lonely when all the people around me want to talk drugs
# 2533                                                                                                                                                                                                                                        We only wish to have nice palms and bleaches, the rest they can keep.
# 1010                                                                                                                                         Umbrella means rain shield in French. Rainfall as an excuse to cancel? There must be another reason. Maybe the hordes of antifa and other scum that will kill Trump.
# 458                                                                                                                            So the Minister of Justice, who I suppose has a leading role in the fight against substance abuse, has no idea how dangerous the individual drugs are? They are crazy, the Swedes.
# 1408                                                                                                                                 Just look at all the Christians shouting and screaming that the OP should be bullied because of a provocative look !! When no wait, I&#39;m thinking of Muslims. My mistake.
# 273                                                                                                                                                                                                                                     I will never again complain about a shitty summer .. Just give me rain ..
# 2598                                                                                                                                                                                                                                        Lel where did you find it? It is known what I would call a tame meme.
# 835                                                                                                                                                                                                                                             Totally agree with KU. Public socialists just greedy teddy bears.
# 1028                                                                                                                                                                                                                             Why is the Swede so humorous and skinned? And then let the hell Skåne come home.
#
#        prob_en  pred_en
# id
# 2065  0.087948    False
# 1017  0.752331     True
# 2415  0.082972    False
# 2704  0.275274    False
# 3224  0.047220    False
# 1860  0.050296    False
# 1541  0.970509     True
# 1322  0.078217    False
# 1174  0.842876     True
# 3438  0.974295     True
# 165   0.122528    False
# 293   0.283236    False
# 3220  0.305164    False
# 1309  0.096757    False
# 1306  0.941944     True
# 3595  0.353553    False
# 875   0.060515    False
# 1538  0.099664    False
# 3254  0.266919    False
# 181   0.966724     True
# 3000  0.105781    False
# 810   0.079138    False
# 486   0.117798    False
# 3232  0.271991    False
# 617   0.150817    False
# 824   0.974996     True
# 1155  0.712936     True
# 909   0.104492    False
# 548   0.185502    False
# 265   0.282931    False
# 858   0.089447    False
# 1974  0.125303    False
# 3301  0.067359    False
# 2533  0.059478    False
# 1010  0.502059     True
# 458   0.142829    False
# 1408  0.082239    False
# 273   0.971565     True
# 2598  0.837643     True
# 835   0.193365    False
# 1028  0.062118    False

# %%
bert_tokenizer = TEXT.tokenize.__self__.bert_tokenizer

def predict_sentence(sentence):
    model.eval()
    inp = torch.tensor(bert_tokenizer.encode(sentence)).view(1, -1).to(device)

    return torch.sigmoid(model(inp))

predict_sentence("Brat!")
# Out:
# tensor([[0.1475]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
predict_sentence("Analgafler")
# Out:
# tensor([[0.3034]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
predict_sentence("Hold dig væk fra vores ø, du dansker lort.")
# Out:
# tensor([[0.3348]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
predict_sentence("Stay away from our island, you danish scum")
# Out:
# tensor([[0.9648]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
predict_sentence("Dungarn lyder bare som et lorte sted på Nørrebro...")
# Out:
# tensor([[0.3415]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
predict_sentence("Dungarn just sounds like a shit place on Nørrebro ...")
# Out:
# tensor([[0.9735]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
predict_sentence("This is really shit. 0/10.")
# Out:
# tensor([[0.9733]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %% [markdown]
# Why this is different from the previous prediction?

# %%
df_da.loc[858].tweet
# Out:
# 'Det her er vitterligt lort. 0/10.'

# %%
predict_sentence(df_da.loc[858].tweet)
# Out:
# tensor([[0.3436]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %%
predict_sentence(df_da.loc[858].en)
# Out:
# tensor([[0.9733]], device='cuda:0', grad_fn=<SigmoidBackward>)

# %% [markdown]
# Ok, something is wrong here, check it out
